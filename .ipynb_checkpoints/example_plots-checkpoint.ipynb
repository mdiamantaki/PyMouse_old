# %%
from access_dj import *
from Database import *
# Out:
# Please enter DataJoint username:  eflab
# Please enter DataJoint password:  ········
# Connecting eflab@139.91.171.210:3306

# %%
# to plot one animal, use animal_id
MouseWeight.plot(MouseWeight, 'animal_id = 15426')

# %%
# to plot more than 1 animal, use []
MouseWeight.plot(MouseWeight, ['animal_id = 12815', 'animal_id = 15426'])

# %%
# to plot all animals, use 'all'
MouseWeight.plot(MouseWeight, 'all')

# %%
# or nothing
# also plots all animals
MouseWeight.plot(MouseWeight)

# %%
LiquidDelivery.plot (LiquidDelivery, 'animal_id = 15426 ')
# Out:
# /mnt/lab/users/zoi/Database.py:243: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_reward'][kk] = t_count[idx][j] * df['reward_amount'][kk]

# %%
LiquidDelivery.plot (LiquidDelivery,['animal_id = 12815', 'animal_id = 15426'])
# Out:
# /mnt/lab/users/zoi/Database.py:243: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_reward'][kk] = t_count[idx][j] * df['reward_amount'][kk]

# %%
LiquidDelivery.plot (LiquidDelivery,'all')
# Out:
# /mnt/lab/users/zoi/Database.py:243: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_reward'][kk] = t_count[idx][j] * df['reward_amount'][kk]
